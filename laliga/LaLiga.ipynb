# %% [markdown]
# # La Liga

# %% [markdown]
# Temporada 08/09

# %%
import pandas as ps
import matplotlib.pyplot as plt
import numpy as np

# %%
df_s08 = ps.read_csv("../datasets/spanish-la-liga_zip/data/season-0809_csv.csv")
df_s09 = ps.read_csv("../datasets/spanish-la-liga_zip/data/season-0910_csv.csv")

# %%
df_s08.head(10)
# Out:
#          Date    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  HS  \
# 0  2008-08-30     Espanol   Valladolid     1     0   H     0     0   D  10
# 1  2008-08-30    Valencia     Mallorca     3     0   H     2     0   H  17
# 2  2008-08-31  Ath Bilbao      Almeria     1     3   A     0     2   A  10
# 3  2008-08-31  Ath Madrid       Malaga     4     0   H     3     0   H  25
# 4  2008-08-31       Betis   Recreativo     0     1   A     0     1   A   8
# 5  2008-08-31   La Coruna  Real Madrid     2     1   H     1     0   H  11
# 6  2008-08-31    Numancia    Barcelona     1     0   H     1     0   H   5
# 7  2008-08-31     Osasuna   Villarreal     1     1   D     0     0   D  10
# 8  2008-08-31   Santander      Sevilla     1     1   D     0     0   D   7
# 9  2008-08-31    Sp Gijon       Getafe     1     2   A     1     1   D  13
#
#   ...  HST  AST  HF  AF  HC  AC  HY  AY  HR  AR
# 0 ...    2    1  18  17   1   9   3   5   0   0
# ...

# %%
df_s08.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     1.660526    1.236842    0.786842    0.552632   14.660526   11.744737
# std      1.336723    1.172108    0.990368    0.747815    5.226078    4.685981
# min      0.000000    0.000000    0.000000    0.000000    3.000000    1.000000
# 25%      1.000000    0.000000    0.000000    0.000000   11.000000    8.000000
# 50%      1.000000    1.000000    1.000000    0.000000   14.000000   11.000000
# 75%      2.000000    2.000000    1.000000    1.000000   18.000000   15.000000
# max      7.000000    6.000000    6.000000    3.000000   32.000000   33.000000
#
#               HST         AST          HF          AF          HC          AC  \
# count  380.000000  380.000000  380.000000  380.000000  380.000000  380.000000
# mean     5.407895    4.113158   16.757895   16.544737    5.918421    4.342105
# ...

# %%
figure, axs = plt.subplots(2,2, sharey=True, sharex=True)
df_s08.plot(kind="scatter",x="HS",y="HST",ax=axs[0][0])
df_s09.plot(kind="scatter",x="HS",y="HST",ax=axs[0][1])

# %% [markdown]
# ## Histograma
# * con bins definimos la cantidad de intervalos

# %%
plt.hist(df_s08["HS"],bins=10)
plt.xlabel("Tiros por equipo local")
# Out:
# Text(0.5, 0, 'Tiros por equipo local')

# %%
k = 1+int(np.ceil(np.log2(380)))
plt.hist(df_s08["HS"],bins= k)
plt.xlabel("Tiros por equipo local")
# Out:
# Text(0.5, 0, 'Tiros por equipo local')

# %% [markdown]
# # Boxplot

# %%
plt.boxplot(df_s08["HS"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x183bdd907f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x183bdd99160>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x183bdd90a58>],
#  'medians': [<matplotlib.lines.Line2D at 0x183bdd997f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x183bdd99b38>],
#  'means': []}

# %%
plt.boxplot(df_s09["HS"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x183bddecda0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x183bddf66d8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x183bddecc50>],
#  'medians': [<matplotlib.lines.Line2D at 0x183bddf6d68>],
#  'fliers': [<matplotlib.lines.Line2D at 0x183bddf6e48>],
#  'means': []}

# %%
plt.boxplot(df_s08["AS"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x183be1d8a20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x183be1d8e48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x183be1d86d8>],
#  'medians': [<matplotlib.lines.Line2D at 0x183be1e3780>],
#  'fliers': [<matplotlib.lines.Line2D at 0x183be1e3ac8>],
#  'means': []}

# %%
plt.boxplot(df_s09["AS"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x183be2384a8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x183be238b38>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x183be2380f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x183be238f60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x183be240550>],
#  'means': []}

# %% [markdown]
# # Rango intercuartilico
# Todos los que estan 1.5 afuera de la diferencia entre percentil 25 y 75 son outliers.

# %%
df_s09["AS"].describe()
# Out:
# count    380.000000
# mean      11.344737
# std        4.662159
# min        0.000000
# 25%        8.000000
# 50%       11.000000
# 75%       14.000000
# max       32.000000
# Name: AS, dtype: float64

# %%
IQR = df_s09["AS"].quantile(0.75) -  df_s09["AS"].quantile(0.25)
IQR
# Out:
# 6.0

# %%
# inferior
inferior =  df_s09["AS"].quantile(0.25) - 1.5 * IQR
inferior
# Out:
# -1.0

# %%
# superior
superior =  df_s09["AS"].quantile(0.75) + 1.5 * IQR
superior
# Out:
# 23.0

# %% [markdown]
# ## subconjunto de datos

# %%
df09_2 = df_s09[df_s09["AS"]>5]
df09_2.describe()
# Out:
#              FTHG        FTAG        HTHG        HTAG          HS          AS  \
# count  343.000000  343.000000  343.000000  343.000000  343.000000  343.000000
# mean     1.583090    1.183673    0.705539    0.504373   14.545190   12.104956
# std      1.262808    1.138672    0.832911    0.720914    5.383821    4.244784
# min      0.000000    0.000000    0.000000    0.000000    3.000000    6.000000
# 25%      1.000000    0.000000    0.000000    0.000000   11.000000    9.000000
# 50%      1.000000    1.000000    1.000000    0.000000   14.000000   11.000000
# 75%      2.000000    2.000000    1.000000    1.000000   18.000000   15.000000
# max      6.000000    5.000000    4.000000    4.000000   37.000000   32.000000
#
#               HST         AST          HF          AF          HC          AC  \
# count  343.000000  343.000000  343.000000  343.000000  343.000000  343.000000
# mean     5.212828    4.344023   16.204082   15.699708    6.081633    4.816327
# ...

# %%
# partidos ganados por el visitante
df_s09_visitantes = df_s09[df_s09["HTR"]=="A"]
df_s09_visitantes.describe()
# Out:
#             FTHG       FTAG       HTHG       HTAG         HS         AS  \
# count  73.000000  73.000000  73.000000  73.000000  73.000000  73.000000
# mean    0.986301   2.328767   0.095890   1.493151  13.342466  12.315068
# std     1.006826   1.131061   0.296479   0.709524   5.662300   4.508870
# min     0.000000   1.000000   0.000000   1.000000   3.000000   2.000000
# 25%     0.000000   1.000000   0.000000   1.000000  10.000000   9.000000
# 50%     1.000000   2.000000   0.000000   1.000000  12.000000  12.000000
# 75%     2.000000   3.000000   0.000000   2.000000  16.000000  15.000000
# max     4.000000   5.000000   1.000000   4.000000  34.000000  22.000000
#
#              HST        AST         HF         AF         HC         AC  \
# count  73.000000  73.000000  73.000000  73.000000  73.000000  73.000000
# mean    4.328767   4.849315  16.287671  15.630137   6.068493   4.534247
# std     2.309731   2.343260   5.723925   4.578048   3.313813   2.192678
# ...

# %%
# partidos ganados por el visitante
df_s09_visitantes = df_s09[(df_s09["FTR"]=="A") & (df_s09["HTR"]=="D")]
df_s09_visitantes.describe()
# Out:
#             FTHG       FTAG       HTHG       HTAG         HS         AS  \
# count  36.000000  36.000000  36.000000  36.000000  36.000000  36.000000
# mean    0.583333   2.166667   0.305556   0.305556  12.111111  13.083333
# std     0.649175   0.910259   0.467177   0.467177   4.670747   5.134616
# min     0.000000   1.000000   0.000000   0.000000   4.000000   7.000000
# 25%     0.000000   1.750000   0.000000   0.000000   8.750000   9.000000
# 50%     0.500000   2.000000   0.000000   0.000000  12.000000  12.000000
# 75%     1.000000   3.000000   1.000000   1.000000  15.250000  15.000000
# max     2.000000   4.000000   1.000000   1.000000  23.000000  32.000000
#
#              HST        AST         HF         AF         HC         AC  \
# count  36.000000  36.000000  36.000000  36.000000  36.000000  36.000000
# mean    3.500000   5.666667  17.694444  16.888889   5.444444   5.222222
# std     1.594634   2.976095   4.083552   3.275692   2.970757   2.737163
# ...

# %%
wc2018 = ps.read_csv("../datasets/world_cup_2018_stats.csv")
wc2018.describe()
# Out:
#              Game   Goals For  Goals Against  Pen Shootout For  \
# count  128.000000  128.000000     128.000000          8.000000
# mean    32.500000    1.320312       1.320312          3.250000
# std     18.545539    1.156519       1.156519          0.707107
# min      1.000000    0.000000       0.000000          2.000000
# 25%     16.750000    0.000000       0.000000          3.000000
# 50%     32.500000    1.000000       1.000000          3.000000
# 75%     48.250000    2.000000       2.000000          4.000000
# max     64.000000    6.000000       6.000000          4.000000
#
#        Pen Shootout Against    Attempts   On-Target  Off-Target     Blocked  \
# count              8.000000  128.000000  128.000000  128.000000  128.000000
# mean               3.250000   12.593750    3.914062    5.312500    3.359375
# std                0.707107    5.245827    2.234403    2.383506    2.403195
# min                2.000000    3.000000    0.000000    1.000000    0.000000
# ...

# %%
# Out:
#      Game                     Group            Team        Opponent Home/Away  \
# 0       1                         A          Russia    Saudi Arabia      home
# 1       1                         A    Saudi Arabia          Russia      away
# 2       2                         A           Egypt         Uruguay      home
# 3       2                         A         Uruguay           Egypt      away
# 4       3                         B         Morocco         IR Iran      home
# 5       3                         B         IR Iran         Morocco      away
# 6       4                         B        Portugal           Spain      home
# 7       4                         B           Spain        Portugal      away
# 8       5                         C          France       Australia      home
# 9       5                         C       Australia          France      away
# 10      6                         D       Argentina         Iceland      home
# ...

# %%
plt.hist(wc2018["Ball possession %"],bins=20)
# Out:
# (array([ 1.,  2.,  4.,  2.,  4.,  7., 14., 10., 11.,  8., 10., 10., 11.,
#         10., 11.,  3.,  3.,  2.,  4.,  1.]),
#  array([25. , 27.5, 30. , 32.5, 35. , 37.5, 40. , 42.5, 45. , 47.5, 50. ,
#         52.5, 55. , 57.5, 60. , 62.5, 65. , 67.5, 70. , 72.5, 75. ]),
#  <a list of 20 Patch objects>)
